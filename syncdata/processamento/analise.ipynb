# %%
import polars as pl
from pathlib import Path

data_path = Path(__name__).parent.absolute().parent / "datasets"

# %%
dfs = []

for files in data_path.rglob("*.parquet"):
    df = pl.read_parquet(files)
    dfs.append(df)

df_final = pl.concat(dfs, rechunk=True, )
df_final.write_parquet(data_path.parent.absolute() / "data" / "ACGRBR2000-2025.parquet")

# %%
lf = pl.scan_parquet("/home/igor-ryan/Documentos/Workspace/SyncData/syncdata/data/ACGRBR2000-2025.parquet", rechunk=True, low_memory=True)

# %%
lf.collect()
# Out:
# shape: (5_148_610, 54)
# ┌────────┬───────────┬────────────┬─────────┬───┬────────┬──────────┬──────────┬─────┐
# │ TP_NOT ┆ ID_AGRAVO ┆ DT_NOTIFIC ┆ SEM_NOT ┆ … ┆ REGIME ┆ EVOLUCAO ┆ DT_OBITO ┆ CAT │
# │ ---    ┆ ---       ┆ ---        ┆ ---     ┆   ┆ ---    ┆ ---      ┆ ---      ┆ --- │
# │ str    ┆ str       ┆ str        ┆ str     ┆   ┆ str    ┆ str      ┆ str      ┆ str │
# ╞════════╪═══════════╪════════════╪═════════╪═══╪════════╪══════════╪══════════╪═════╡
# │ 2      ┆ Y96       ┆ 20070104   ┆ 200701  ┆ … ┆ 3      ┆ 9        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20070127   ┆ 200704  ┆ … ┆ 2      ┆ 9        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20070131   ┆ 200705  ┆ … ┆ 2      ┆ 9        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20070128   ┆ 200705  ┆ … ┆ 2      ┆ 9        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20070123   ┆ 200704  ┆ … ┆ 3      ┆ 9        ┆          ┆ 1   │
# ...
