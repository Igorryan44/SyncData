# %%
import polars as pl
from pathlib import Path

data_path = Path(__name__).parent.absolute().parent / "data"

# %%
lf = pl.scan_parquet(f"{data_path}/ACGRBR.parquet", rechunk=True, low_memory=True)

# %%
lf.collect()
# Out:
# shape: (2_684_958, 54)
# ┌────────┬───────────┬────────────┬─────────┬───┬────────┬──────────┬──────────┬─────┐
# │ TP_NOT ┆ ID_AGRAVO ┆ DT_NOTIFIC ┆ SEM_NOT ┆ … ┆ REGIME ┆ EVOLUCAO ┆ DT_OBITO ┆ CAT │
# │ ---    ┆ ---       ┆ ---        ┆ ---     ┆   ┆ ---    ┆ ---      ┆ ---      ┆ --- │
# │ str    ┆ str       ┆ str        ┆ str     ┆   ┆ str    ┆ str      ┆ str      ┆ str │
# ╞════════╪═══════════╪════════════╪═════════╪═══╪════════╪══════════╪══════════╪═════╡
# │ 2      ┆ Y96       ┆ 20060122   ┆ 200604  ┆ … ┆ 1      ┆ 9        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20060111   ┆ 200602  ┆ … ┆ 2      ┆ 9        ┆          ┆ 9   │
# │ 2      ┆ Y96       ┆ 20060226   ┆ 200609  ┆ … ┆ 9      ┆ 9        ┆          ┆ 9   │
# │ 2      ┆ Y96       ┆ 20060203   ┆ 200605  ┆ … ┆ 1      ┆ 4        ┆          ┆ 1   │
# │ 2      ┆ Y96       ┆ 20060222   ┆ 200608  ┆ … ┆ 2      ┆ 9        ┆          ┆ 9   │
# ...
