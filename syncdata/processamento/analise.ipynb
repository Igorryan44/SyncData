# %%
import polars as pl
from pysus import SINAN
from pathlib import Path

sinan = SINAN().load()
years = [i for i in range(2025) if i >1999]

data_path = Path(__name__).parent.absolute().parent / "datasets"
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[2], line 5
#       2 from pysus import SINAN
#       3 from pathlib import Path
# ----> 5 sinan = SINAN().load()
#       6 years = [i for i in range(2025) if i >1999]
#       8 data_path = Path(__name__).parent.absolute().parent / "datasets"
#
# File ~/.cache/pypoetry/virtualenvs/syncdata-gv_cdwdk-py3.10/lib/python3.10/site-packages/pysus/ftp/__init__.py:517, in Database.load(self, directories)
#     514     if not isinstance(directory, Directory):
#     515         raise ValueError("Invalid directory provided.")
# --> 517     directory.load()
#     518     self.__content__.update(directory.__content__)
#     519 return self
#
# File ~/.cache/pypoetry/virtualenvs/syncdata-gv_cdwdk-py3.10/lib/python3.10/site-packages/pysus/ftp/__init__.py:364, in Directory.load(self)
#     362 def load(self) -> Self:
# ...

# %%
files = sinan.get_files(dis_code="ACGR", year=years) # Extração dos dados de Acidente de Trabalho de 2000 a 2025
sinan.download(files, local_dir="data/") # Download dos arquivos

# %%
dfs = []

for file in data_path.rglob("*.parquet"):
    if file.is_file():
        df = pl.read_parquet(file)
        dfs.append(df)

df_final = pl.concat(dfs, rechunk=True)
df_final.write_parquet(f"{data_path}ACGRBR.parquet")
